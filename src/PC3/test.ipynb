# %%
import pandas as pd
basedir = "./../../"

# %%
dfL  = pd.read_csv(f"{basedir}data/ml-25m/links.csv")
dfM  = pd.read_csv(f"{basedir}data/ml-25m/movies.csv")
dfR  = pd.read_csv(f"{basedir}data/ml-25m/ratings.csv")
dfT  = pd.read_csv(f"{basedir}data/ml-25m/tags.csv")

# %%
dfL.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
dfM.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
dfR.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
dfR
# Out:
#           userId  movieId  rating   timestamp
# 0              1      296     5.0  1147880044
# 1              1      306     3.5  1147868817
# 2              1      307     5.0  1147868828
# 3              1      665     5.0  1147878820
# 4              1      899     3.5  1147868510
# ...          ...      ...     ...         ...
# 25000090  162541    50872     4.5  1240953372
# 25000091  162541    55768     2.5  1240951998
# 25000092  162541    56176     2.0  1240950697
# 25000093  162541    58559     4.0  1240953434
# 25000094  162541    63876     5.0  1240952515
#
# [25000095 rows x 4 columns]

# %%
dfT.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
dfT
# Out:
#          userId  movieId                  tag   timestamp
# 0             3      260              classic  1439472355
# 1             3      260               sci-fi  1439472256
# 2             4     1732          dark comedy  1573943598
# 3             4     1732       great dialogue  1573943604
# 4             4     7569     so bad it's good  1573943455
# ...         ...      ...                  ...         ...
# 1093355  162521    66934  Neil Patrick Harris  1427311611
# 1093356  162521   103341     cornetto trilogy  1427311259
# 1093357  162534   189169               comedy  1527518175
# 1093358  162534   189169             disabled  1527518181
# 1093359  162534   189169              robbery  1527518193
#
# [1093360 rows x 4 columns]
